-- %%
INSERT INTO ecommerce_analytical.data_warehouse.dim_customer
SELECT
order_number AS order_id,
customer_id,
product_id,
promo_id,
date_format( to_timestamp(order_datetime), 'yyyyMMdd') AS order_date_key,
qty as quantity,
price,
qty*price as amount
from batch1.data.sales_orders
